# %% [markdown]
# # SHINE: Entropy-Guided Digital Twins reconstruction demo
# written by Dexiang Zong
# CardioVascular Systems Imaging and Artificial Intelligence (CVS.AI)
# National Heart Research Institute Singapore (NHRIS)
# national heart center singarpore
#
# This interactive notebook demonstrates how to load a patient mesh, co-register sparse LGE-MRI probability slices, set up the Bayesian SIREN, and execute the entropy-guided manifold fitting reconstruction.

# %%
import torch
import numpy as np
from shine.models.siren import BayesianSIREN
from shine.loss.dirichlet import EntropyWeightedLoss

print("PyTorch version:", torch.__version__)
print("SHINE imports successful!")
